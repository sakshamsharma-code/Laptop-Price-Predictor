# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Final Project\Laptop-Price-Predictor\data\Laptop_Price.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df.drop(columns=['weight','Number of Ratings', 'Number of Reviews'], axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating'],
#       dtype='object')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
num=df.select_dtypes(exclude='object')

# %%
num.columns
# Out:
# Index(['Price'], dtype='object')

# %%
char=df.select_dtypes(include='object')

# %%
char.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
char['brand'] = le.fit_transform(char['brand'])
char['processor_brand'] = le.fit_transform(char['processor_brand'])
char['processor_name'] = le.fit_transform(char['processor_name'])
char['processor_gnrtn'] = le.fit_transform(char['processor_gnrtn'])
char['ram_gb'] = le.fit_transform(char['ram_gb'])
char['ram_type'] = le.fit_transform(char['ram_type'])
char['ssd'] = le.fit_transform(char['ssd'])
char['hdd'] = le.fit_transform(char['hdd'])
char['os'] = le.fit_transform(char['os'])
char['os_bit'] = le.fit_transform(char['os_bit'])
char['graphic_card_gb'] = le.fit_transform(char['graphic_card_gb'])
char['warranty'] = le.fit_transform(char['warranty'])
char['Touchscreen'] = le.fit_transform(char['Touchscreen'].map({'Yes': 1, 'No': 0}))
char['msoffice'] = le.fit_transform(char['msoffice'].map({'Yes': 1, 'No': 0}))
char['rating'] = le.fit_transform(char['rating'])

# %%
char
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# ...

# %%
clean_data=pd.concat([char,num],axis=1)

# %%
clean_data
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1                0       2
# 1        5                1               1                0       2
# 2        5                1               1                0       2
# 3        1                1               2                0       3
# 4        1                1               0                7       2
# ..     ...              ...             ...              ...     ...
# 818      1                0              10                7       2
# 819      1                0              10                7       2
# 820      1                0              10                7       2
# 821      1                0              10                7       2
# 822      5                0               8                0       3
#
#      ram_type  ssd  hdd  os  os_bit  graphic_card_gb  warranty  Touchscreen  \
# ...

# %%
clean_data.to_csv(r"C:\Final Project\Laptop-Price-Predictor\data\Cleaned_Laptop_Price.csv", index=False)
